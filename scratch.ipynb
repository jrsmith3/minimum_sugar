# %%
import requests
import json
import os

# Load credential data from file
with open("credentials.json", "r") as f:
    credentials = json.load(f)

# Load restaurant ids from file
with open ("restaurant_ids.json", "r") as f:
    restaurant_ids = json.load(f)

# %%
restaurant_ids
# Out:
# [{u'id': u'513fbc1283aa2dc80c000053', u'name': u"McDonald's"},
#  {u'id': u'513fbc1283aa2dc80c00000f', u'name': u"Wendy's"},
#  {u'id': u'513fbc1283aa2dc80c000020', u'name': u'Taco Bell'},
#  {u'id': u'513fbc1283aa2dc80c00003a', u'name': u'Qdoba'},
#  {u'id': u'513fbc1283aa2dc80c000002', u'name': u'Chipotle'},
#  {u'id': u'513fbc1283aa2dc80c00003f', u'name': u'Five Guys'}]

# %%
def fetch_subset_menu_item_data(restaurant_id, credentials, offset=0):
    """
    Helper function to fetch a subset of a restaurant's menu item data
    
    Parameters
    ----------
    restaurant_id : str
        Nutritionix unique ID specifying restaurant
    credentials : dict
        Contains API credentials "appID" and "appKey"
    """

    # Set base query URL
    query_url = u"https://api.nutritionix.com/v1_1/search"

    # Include API credentials in POST request
    payload = dict(credentials)
    # Use "filters" key to specify restaurant by ID
    payload["filters"] = {"brand_id": restaurant_id}
    # Use "offset" and "limit" to get different subsets of the total data
    payload["offset"] = offset
    payload["limit"] = 50
    # Request all data from database (according to the [master list](https://docs.google.com/a/nutritionix.com/spreadsheet/ccc?key=0AmQ7yz5GxBrvdFhtRUpPdjl3VWk2U0dvZENyUVNrWGc&usp=drive_web#gid=0))
    payload["fields"] = ["brand_name",
                         "item_name",
                         "brand_id",
                         "item_id",
                         "upc",
                         "item_type",
                         "item_description",
                         "nf_ingredient_statement",
                         "nf_water_grams",
                         "nf_calories",
                         "nf_calories_from_fat",
                         "nf_total_fat",
                         "nf_saturated_fat",
                         "nf_monounsaturated_fat",
                         "nf_polyunsaturated_fat",
                         "nf_trans_fatty_acid",
                         "nf_cholesterol",
                         "nf_sodium",
                         "nf_total_carbohydrate",
                         "nf_dietary_fiber",
                         "nf_sugars",
                         "nf_protein",
                         "nf_vitamin_a_iu",
                         "nf_vitamin_a_dv",
                         "nf_vitamin_c_mg",
                         "nf_vitamin_c_dv",
                         "nf_calcium_mg",
                         "nf_calcium_dv",
                         "nf_iron_mg",
                         "nf_iron_dv",
                         "nf_potassium",
                         "nf_refuse_pct",
                         "nf_servings_per_container",
                         "nf_serving_size_qty",
                         "nf_serving_size_unit",
                         "nf_serving_weight_grams",
                         "allergen_contains_milk",
                         "allergen_contains_eggs",
                         "allergen_contains_fish",
                         "allergen_contains_shellfish",
                         "allergen_contains_tree_nuts",
                         "allergen_contains_peanuts",
                         "allergen_contains_wheat",
                         "allergen_contains_soybeans",
                         "allergen_contains_gluten",
                         "images_front_full_url",
                         "updated_at",
                         "section_ids",]
    
    # Make request by sending payload as json
    r = requests.post(query_url, json=payload)
    
    return r.json()

# %%
# Note McDonalds corresponds to 513fbc1283aa2dc80c000053
# Chipotle corresponds to 513fbc1283aa2dc80c000002
dat = fetch_subset_menu_item_data("513fbc1283aa2dc80c000053", credentials, offset=50)

# %%
dat
# Out:
# {u'hits': [{u'_id': u'513fc9e73fe3ffd403001193',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe, Beverages - Strawberry Banana Smoothie (Small)',
#     u'item_id': u'513fc9e73fe3ffd403001193',
#     u'item_name': u'Strawberry Banana Smoothie (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 8,
#     u'nf_calories': 210,
#     u'nf_calories_from_fat': 5,
#     u'nf_cholesterol': 5,
#     u'nf_dietary_fiber': 3,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 2,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 3,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 12,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 50,
#     u'nf_sugars': 44,
#     u'nf_total_carbohydrate': 47,
#     u'nf_total_fat': 0.5,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 30,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:47.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd403001198',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Desserts & Shakes - Strawberry Sundae',
#     u'item_id': u'513fc9e73fe3ffd403001198',
#     u'item_name': u'Strawberry Sundae',
#     u'item_type': 1,
#     u'nf_calcium_dv': 20,
#     u'nf_calories': 280,
#     u'nf_calories_from_fat': 60,
#     u'nf_cholesterol': 25,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 6,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 4,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'sundae',
#     u'nf_serving_weight_grams': 178,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 85,
#     u'nf_sugars': 45,
#     u'nf_total_carbohydrate': 49,
#     u'nf_total_fat': 6,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 8,
#     u'nf_vitamin_c_dv': 4,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:44.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd40300119e',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Beverages - Sweet Tea (Large)',
#     u'item_id': u'513fc9e73fe3ffd40300119e',
#     u'item_name': u'Sweet Tea (Large)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 0,
#     u'nf_calories': 280,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 1,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 30,
#     u'nf_serving_size_unit': u'fl oz',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 15,
#     u'nf_sugars': 71,
#     u'nf_total_carbohydrate': 71,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd4030011a3',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe, Beverages, Desserts & Shakes - Vanilla McCaf&eacute; Shake (Small)',
#     u'item_id': u'513fc9e73fe3ffd4030011a3',
#     u'item_name': u'Vanilla McCafe Shake (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 40,
#     u'nf_calories': 530,
#     u'nf_calories_from_fat': 140,
#     u'nf_cholesterol': 60,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 11,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 10,
#     u'nf_serving_size_qty': 12,
#     u'nf_serving_size_unit': u'fl oz',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 160,
#     u'nf_sugars': 63,
#     u'nf_total_carbohydrate': 86,
#     u'nf_total_fat': 15,
#     u'nf_trans_fatty_acid': 1,
#     u'nf_vitamin_a_dv': 20,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:48.000Z'}},
#   {u'_id': u'521b95c74a56d006d578b116',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Breakfast - Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)',
#     u'item_id': u'521b95c74a56d006d578b116',
#     u'item_name': u'Bacon, Egg & Cheese Biscuit With Egg Whites (Large Biscuit)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 15,
#     u'nf_calories': 470,
#     u'nf_calories_from_fat': 220,
#     u'nf_cholesterol': 35,
#     u'nf_dietary_fiber': 3,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 15,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 20,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 12,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'meal',
#     u'nf_serving_weight_grams': 167,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 1420,
#     u'nf_sugars': 4,
#     u'nf_total_carbohydrate': 42,
#     u'nf_total_fat': 25,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 6,
#     u'nf_vitamin_c_dv': 8,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:40.000Z'}},
#   {u'_id': u'521b95c74a56d006d578b11c',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Breakfast - Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)',
#     u'item_id': u'521b95c74a56d006d578b11c',
#     u'item_name': u'Big Breakfast With Hotcakes And Egg Whites (Regular Biscuit)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 25,
#     u'nf_calories': 990,
#     u'nf_calories_from_fat': 410,
#     u'nf_cholesterol': 55,
#     u'nf_dietary_fiber': 6,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 30,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 35,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 16,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'meal',
#     u'nf_serving_weight_grams': 423,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 2170,
#     u'nf_sugars': 17,
#     u'nf_total_carbohydrate': 110,
#     u'nf_total_fat': 46,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 2,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:40.000Z'}},
#   {u'_id': u'521b95c74a56d006d578b128',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Burgers & Sandwiches, Chicken & Fish - Premium McWrap Chicken & Ranch (Crispy)',
#     u'item_id': u'521b95c74a56d006d578b128',
#     u'item_name': u'Premium Mcwrap Chicken & Ranch (Crispy)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 20,
#     u'nf_calories': 610,
#     u'nf_calories_from_fat': 280,
#     u'nf_cholesterol': 65,
#     u'nf_dietary_fiber': 3,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 20,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 27,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 8,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'wrap',
#     u'nf_serving_weight_grams': 310,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 1340,
#     u'nf_sugars': 8,
#     u'nf_total_carbohydrate': 56,
#     u'nf_total_fat': 31,
#     u'nf_trans_fatty_acid': 0.5,
#     u'nf_vitamin_a_dv': 60,
#     u'nf_vitamin_c_dv': 15,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:42.000Z'}},
#   {u'_id': u'521b95c74a56d006d578b12e',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Burgers & Sandwiches - Quarter Pounder Deluxe',
#     u'item_id': u'521b95c74a56d006d578b12e',
#     u'item_name': u'Quarter Pounder Deluxe',
#     u'item_type': 1,
#     u'nf_calcium_dv': 30,
#     u'nf_calories': 580,
#     u'nf_calories_from_fat': 280,
#     u'nf_cholesterol': 100,
#     u'nf_dietary_fiber': 3,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 25,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 29,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 13,
#     u'nf_serving_size_qty': 8.9,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 253,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 1200,
#     u'nf_sugars': 11,
#     u'nf_total_carbohydrate': 45,
#     u'nf_total_fat': 32,
#     u'nf_trans_fatty_acid': 1.5,
#     u'nf_vitamin_a_dv': 15,
#     u'nf_vitamin_c_dv': 10,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'521b95c74a56d006d578b130',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Breakfast - Sausage Biscuit with Egg Whites (Regular Size Biscuit)',
#     u'item_id': u'521b95c74a56d006d578b130',
#     u'item_name': u'Sausage Biscuit With Egg Whites (Regular Size Biscuit)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 8,
#     u'nf_calories': 460,
#     u'nf_calories_from_fat': 250,
#     u'nf_cholesterol': 35,
#     u'nf_dietary_fiber': 2,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 15,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 18,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 12,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'meal',
#     u'nf_serving_weight_grams': 167,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 1180,
#     u'nf_sugars': 3,
#     u'nf_total_carbohydrate': 34,
#     u'nf_total_fat': 27,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:42.000Z'}},
#   {u'_id': u'534449c77ba4ca15456f5028',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Burgers & Sandwiches, Chicken & Fish - Bacon Buffalo Ranch McChicken',
#     u'item_id': u'534449c77ba4ca15456f5028',
#     u'item_name': u'Bacon Buffalo Ranch McChicken',
#     u'item_type': 1,
#     u'nf_calcium_dv': 15,
#     u'nf_calories': 440,
#     u'nf_calories_from_fat': 190,
#     u'nf_cholesterol': 55,
#     u'nf_dietary_fiber': 2,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 15,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 20,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 5,
#     u'nf_serving_size_qty': 5.7,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 162,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 1120,
#     u'nf_sugars': 6,
#     u'nf_total_carbohydrate': 41,
#     u'nf_total_fat': 21,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 2,
#     u'nf_vitamin_c_dv': 10,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'534449c77ba4ca15456f502e',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe, Beverages - Premium Roast Iced Coffee (Small)',
#     u'item_id': u'534449c77ba4ca15456f502e',
#     u'item_name': u'Premium Roast Iced Coffee (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 4,
#     u'nf_calories': 140,
#     u'nf_calories_from_fat': 40,
#     u'nf_cholesterol': 15,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 1,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 3,
#     u'nf_serving_size_qty': 16,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 35,
#     u'nf_sugars': 22,
#     u'nf_total_carbohydrate': 23,
#     u'nf_total_fat': 4.5,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 4,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:47.000Z'}},
#   {u'_id': u'534449c8bbe335144597ff2c',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Burgers & Sandwiches, Chicken & Fish - Bacon Cheddar McChicken',
#     u'item_id': u'534449c8bbe335144597ff2c',
#     u'item_name': u'Bacon Cheddar McChicken',
#     u'item_type': 1,
#     u'nf_calcium_dv': 20,
#     u'nf_calories': 490,
#     u'nf_calories_from_fat': 220,
#     u'nf_cholesterol': 70,
#     u'nf_dietary_fiber': 2,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 15,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 22,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 7,
#     u'nf_serving_size_qty': 6.1,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 172,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 1120,
#     u'nf_sugars': 6,
#     u'nf_total_carbohydrate': 43,
#     u'nf_total_fat': 25,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 4,
#     u'nf_vitamin_c_dv': 10,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'ae495051f244ebefaae944e2',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe - McCaf&eacute; Iced Caramel Mocha (Large)',
#     u'item_id': u'ae495051f244ebefaae944e2',
#     u'item_name': u'McCafe Iced Caramel Mocha (Large)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 40,
#     u'nf_calories': 450,
#     u'nf_calories_from_fat': 140,
#     u'nf_cholesterol': 50,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 4,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 13,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 9,
#     u'nf_serving_size_qty': 22,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 250,
#     u'nf_sugars': 58,
#     u'nf_total_carbohydrate': 64,
#     u'nf_total_fat': 16,
#     u'nf_trans_fatty_acid': 0.5,
#     u'nf_vitamin_a_dv': 15,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:47.000Z'}},
#   {u'_id': u'23cb594904816ae840edf65d',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb594904816ae840edf65d',
#     u'item_name': u'Fried Cherry Pie',
#     u'item_type': 1,
#     u'nf_calcium_dv': 2,
#     u'nf_calories': 230,
#     u'nf_calories_from_fat': 90,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 6,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 2,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 3.5,
#     u'nf_serving_size_qty': 2.9,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 81,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 135,
#     u'nf_sugars': 15,
#     u'nf_total_carbohydrate': 33,
#     u'nf_total_fat': 10,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 6,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb59490ed045f0643b1c45',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb59490ed045f0643b1c45',
#     u'item_name': u'Iced Strawberry Lemonade (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 2,
#     u'nf_calories': 120,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 2,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 1,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 13.8,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 390,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 10,
#     u'nf_sugars': 28,
#     u'nf_total_carbohydrate': 32,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 50,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb5949515a53a1c93ab1e3',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb5949515a53a1c93ab1e3',
#     u'item_name': u'Shamrock McCafe Shake (Large)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 60,
#     u'nf_calories': 820,
#     u'nf_calories_from_fat': 210,
#     u'nf_cholesterol': 90,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 18,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 15,
#     u'nf_serving_size_qty': 22,
#     u'nf_serving_size_unit': u'fl oz',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 260,
#     u'nf_sugars': 115,
#     u'nf_total_carbohydrate': 135,
#     u'nf_total_fat': 23,
#     u'nf_trans_fatty_acid': 1,
#     u'nf_vitamin_a_dv': 30,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb59497bc13c39ce7b95cb',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb59497bc13c39ce7b95cb',
#     u'item_name': u'Southern Style Frozen Strawberry Lemonade (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 0,
#     u'nf_calories': 260,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 0,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 14.1,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 399,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 170,
#     u'nf_sugars': 63,
#     u'nf_total_carbohydrate': 68,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 15,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb594989518baa90a3314e',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb594989518baa90a3314e',
#     u'item_name': u'Apple Slices',
#     u'item_type': 1,
#     u'nf_calcium_dv': 2,
#     u'nf_calories': 15,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 0,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 1.2,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 34,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 0,
#     u'nf_sugars': 3,
#     u'nf_total_carbohydrate': 4,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 160,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:38:31.000Z'}},
#   {u'_id': u'23cb59498f6ed8cacb4f92af',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb59498f6ed8cacb4f92af',
#     u'item_name': u'Red Flash (Extra Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 0,
#     u'nf_calories': 110,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 0,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 9.2,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 260,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 0,
#     u'nf_sugars': 29,
#     u'nf_total_carbohydrate': 29,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb59498f7c429290169bfe',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb59498f7c429290169bfe',
#     u'item_name': u'Premium Asian Salad With Crispy Chicken',
#     u'item_type': 1,
#     u'nf_calcium_dv': 15,
#     u'nf_calories': 410,
#     u'nf_calories_from_fat': 200,
#     u'nf_cholesterol': 45,
#     u'nf_dietary_fiber': 5,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 15,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 23,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 3,
#     u'nf_serving_size_qty': 10.4,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 294,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 740,
#     u'nf_sugars': 12,
#     u'nf_total_carbohydrate': 32,
#     u'nf_total_fat': 22,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 180,
#     u'nf_vitamin_c_dv': 70,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb5949c72e993726f9f190',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb5949c72e993726f9f190',
#     u'item_name': u'Southern Style Frozen Lemonade (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 0,
#     u'nf_calories': 230,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 0,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 12.6,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 357,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 170,
#     u'nf_sugars': 56,
#     u'nf_total_carbohydrate': 61,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb5949c8b6bc0fbee057fe',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb5949c8b6bc0fbee057fe',
#     u'item_name': u'McCafe White Chocolate Mocha (Large)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 50,
#     u'nf_calories': 480,
#     u'nf_calories_from_fat': 140,
#     u'nf_cholesterol': 50,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 2,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 17,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 9,
#     u'nf_serving_size_qty': 20,
#     u'nf_serving_size_unit': u'fl oz',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 250,
#     u'nf_sugars': 65,
#     u'nf_total_carbohydrate': 70,
#     u'nf_total_fat': 16,
#     u'nf_trans_fatty_acid': 0.5,
#     u'nf_vitamin_a_dv': 15,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb5949f259be67aead0432',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb5949f259be67aead0432',
#     u'item_name': u'Oreo Frappe (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 20,
#     u'nf_calories': 540,
#     u'nf_calories_from_fat': 180,
#     u'nf_cholesterol': 60,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 6,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 7,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 12,
#     u'nf_serving_size_qty': 14.6,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 413,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 170,
#     u'nf_sugars': 68,
#     u'nf_total_carbohydrate': 82,
#     u'nf_total_fat': 20,
#     u'nf_trans_fatty_acid': 1,
#     u'nf_vitamin_a_dv': 15,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd403001098',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Breakfast - Bacon, Egg & Cheese Biscuit (Regular Size Biscuit)',
#     u'item_id': u'513fc9e73fe3ffd403001098',
#     u'item_name': u'Bacon, Egg & Cheese Biscuit (Regular Size Biscuit)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 15,
#     u'nf_calories': 460,
#     u'nf_calories_from_fat': 230,
#     u'nf_cholesterol': 250,
#     u'nf_dietary_fiber': 2,
#     u'nf_ingredient_statement': u'Biscuit (Regular) Allergens: WHEAT, MILK AND SOY LECITHIN, SOY LECITHIN Ingredients: Enriched Flour (Bleached Wheat Flour, Niacin, Reduced Iron, Thiamin Mononitrate, Riboflavin, Folic Acid), Cultured Nonfat Buttermilk, Vegetable Oil (Palm Oil, Palm Kernel Oil), Water, Leavening (Baking Soda, Sodium Aluminum Phosphate, Monocalcium Phosphate), Contains 2% Or Less: Salt, Sugar, Modified Cellulose, Wheat Protein Isolate, Natural Flavor (Dairy and Vegetable Source), Soy Lecithin. CONTAINS: WHEAT, MILK AND SOY LECITHIN. Prepared with Liquid Margarine: Liquid Soybean Oil and Hydrogenated Cottonseed and Soybean Oils, Water, Partially Hydrogenated Soybean Oil, Salt, Soy Lecithin, Mono and Diglycerides, Sodium Benzoate and Potassium Sorbate (Preservatives), Artificial Flavor, Citric Acid, Vitamin A Palmitate, Beta Carotene (Color). CONTAINS: SOY LECITHIN. Bacon Pork Bellies Cured with Water, Salt, Sugar, Natural Smoke Flavor (Plant Source), Sodium Phosphate, Sodium Erythorbate, Sodium Nitrite. Folded Egg Allergens: EGG, SOY LECITHIN, SOY LECITHIN Pasteurized Whole Eggs, Modified Food Starch, Soybean Oil, Natural Flavors (Plant Source), Sodium Acid Pyrophosphate, Carrageenan, Flavor Enhancer (Salt, Maltodextrin, Natural Flavor [Plant Source], Spices, Herb, Turmeric [Color]), Monosodium Phosphate, Citric Acid, Soy Lecithin. CONTAINS: EGG, SOY LECITHIN. Prepared with Liquid Margarine: Liquid Soybean Oil and Hydrogenated Cottonseed and Soybean Oils, Water, Partially Hydrogenated Soybean Oil, Salt, Soy Lecithin, Mono and Diglycerides, Sodium Benzoate and Potassium Sorbate (Preservatives), Artificial Flavor, Citric Acid, Vitamin A Palmitate, Beta Carotene (Color). CONTAINS: SOY LECITHIN. Pasteurized Process American Cheese Allergens: MILK AND SOY LECITHIN Milk, Cream, Water, Cheese Culture, Sodium Citrate, Contains 2% or Less of: Salt, Citric Acid, Sodium Phosphate, Sorbic Acid (Preservative), Lactic Acid, Acetic Acid, Enzymes, Sodium Pyrophosphate, Natural Flavor (Dairy Source), Color Added, Soy Lecithin (Added for Slice Separation). CONTAINS: MILK AND SOY LECITHIN',
#     u'nf_iron_dv': 15,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 19,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 13,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'biscuit',
#     u'nf_serving_weight_grams': 150,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 1300,
#     u'nf_sugars': 3,
#     u'nf_total_carbohydrate': 38,
#     u'nf_total_fat': 26,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 10,
#     u'nf_vitamin_c_dv': 8,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:39.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd40300109e',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Breakfast - Big Breakfast with Hotcakes (Regular Size Biscuit)',
#     u'item_id': u'513fc9e73fe3ffd40300109e',
#     u'item_name': u'Big Breakfast With Hotcakes (Regular Size Biscuit)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 25,
#     u'nf_calories': 1090,
#     u'nf_calories_from_fat': 510,
#     u'nf_cholesterol': 575,
#     u'nf_dietary_fiber': 6,
#     u'nf_ingredient_statement': u'Scrambled Eggs Allergens: EGG, SOY LECITHIN Pasteurized whole eggs with sodium phosphate, citric acid and monosodium phosphate (added to preserve color), nisin preparation (preservative). CONTAINS: EGG. Prepared with Liquid Margarine: Liquid soybean oil and hydrogenated cottonseed and soybean oils, water, partially hydrogenated soybean oil, salt, soy lecithin, mono-and diglycerides, sodium benzoate and potassium sorbate (preservatives), artificial flavor, citric acid, vitamin A palmitate, beta carotene (color). CONTAINS: SOY LECITHIN. Sausage Patty Pork, water, seasoning (salt, corn syrup solids, spices, dextrose, sugar, spice extractives), preservatives (BHA, citric acid and propyl gallate). Biscuit (Regular) Allergens: WHEAT, MILK AND SOY LECITHIN, SOY LECITHIN Ingredients: Enriched Flour (Bleached Wheat Flour, Niacin, Reduced Iron, Thiamin Mononitrate, Riboflavin, Folic Acid), Cultured Nonfat Buttermilk, Vegetable Oil (Palm Oil, Palm Kernel Oil), Water, Leavening (Baking Soda, Sodium Aluminum Phosphate, Monocalcium Phosphate), Contains 2% Or Less: Salt, Sugar, Modified Cellulose, Wheat Protein Isolate, Natural Flavor (Dairy and Vegetable Source), Soy Lecithin. CONTAINS: WHEAT, MILK AND SOY LECITHIN. Prepared with Liquid Margarine: Liquid Soybean Oil and Hydrogenated Cottonseed and Soybean Oils, Water, Partially Hydrogenated Soybean Oil, Salt, Soy Lecithin, Mono and Diglycerides, Sodium Benzoate and Potassium Sorbate (Preservatives), Artificial Flavor, Citric Acid, Vitamin A Palmitate, Beta Carotene (Color). CONTAINS: SOY LECITHIN. Hash Brown Allergens: WHEAT AND MILK Potatoes, vegetable oil (canola oil, hydrogenated soybean oil, natural beef flavor [wheat and milk derivatives]*, citric acid [preservative]), salt, corn flour, dehydrated potato, dextrose, sodium acid pyrophosphate (maintain color), extractives of black pepper. Prepared in vegetable oil (Canola oil, corn oil, soybean oil, hydrogenated soybean oil with TBHQ and citric acid added to preserve freshness). Dimethylpolysiloxane added as an antifoaming agent. * CONTAINS: WHEAT AND MILK. (Natural beef flavor contains hydrolyzed wheat and hydrolyzed milk as starting ingredients). Hotcakes (3) Allergens: WHEAT, MILK, EGG AND SOY LECITHIN Water, enriched flour (wheat flour, niacin, reduced iron, thiamin mononitrate, riboflavin, folic acid), whey powder, yellow corn flour, soybean oil, sugar, whole eggs, contains 2% or less of the following: leavening (sodium bicarbonate, sodium aluminum phosphate, monocalcium phosphate), dextrose, egg whites, emulsifier (mono-and diglycerides, propylene glycol monoester, sodium stearoyl lactylate), salt, artificial flavor, xanthan gum, beta carotene (color), soy lecithin (processing aid). CONTAINS: WHEAT, MILK, EGG AND SOY LECITHIN.',
#     u'nf_iron_dv': 40,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 36,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 19,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'meal',
#     u'nf_serving_weight_grams': 420,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 2150,
#     u'nf_sugars': 17,
#     u'nf_total_carbohydrate': 111,
#     u'nf_total_fat': 56,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 15,
#     u'nf_vitamin_c_dv': 2,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:39.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd4030010a3',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe - Caramel Latte (Small)',
#     u'item_id': u'513fc9e73fe3ffd4030010a3',
#     u'item_name': u'Caramel Latte (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 30,
#     u'nf_calories': 270,
#     u'nf_calories_from_fat': 80,
#     u'nf_cholesterol': 25,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': u'Whole Milk Milk, vitamin D3 added. Espresso Caramel Syrup Sugar, water, fructose, natural (plant source) and artificial flavor, salt, caramel color (with sulfites), potassium sorbate (preservative), citric acid, malic acid.',
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 9,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 5,
#     u'nf_serving_size_qty': 12,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 115,
#     u'nf_sugars': 38,
#     u'nf_total_carbohydrate': 40,
#     u'nf_total_fat': 9,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 8,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:43.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd4030010a8',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Chicken & Fish - Chicken McNuggets&reg; (10 piece)',
#     u'item_id': u'513fc9e73fe3ffd4030010a8',
#     u'item_name': u'Chicken McNuggets (10 Piece)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 2,
#     u'nf_calories': 470,
#     u'nf_calories_from_fat': 270,
#     u'nf_cholesterol': 65,
#     u'nf_dietary_fiber': 2,
#     u'nf_ingredient_statement': u'Allergens: WHEAT White boneless chicken, water, food starch-modified, salt, seasoning [autolyzed yeast extract, salt, wheat starch, natural flavoring (botanical source), safflower oil, dextrose, citric acid], sodium phosphates, natural flavor (botanical source). Battered and breaded with: water, enriched flour (bleached wheat flour, niacin, reduced iron, thiamin mononitrate, riboflavin, folic acid), yellow corn flour, bleached wheat flour, food starch-modified, salt, leavening (baking soda, sodium acid pyrophosphate, sodium aluminum phosphate, monocalcium phosphate, calcium lactate), spices, wheat starch, dextrose, corn starch. CONTAINS: WHEAT. Prepared in vegetable oil (Canola oil, corn oil, soybean oil, hydrogenated soybean oil with TBHQ and citric acid added to preserve freshness). Dimethylpolysiloxane added as an antifoaming agent.',
#     u'nf_iron_dv': 6,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 22,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 5,
#     u'nf_serving_size_qty': 10,
#     u'nf_serving_size_unit': u'pieces',
#     u'nf_serving_weight_grams': 162,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 900,
#     u'nf_sugars': 0,
#     u'nf_total_carbohydrate': 30,
#     u'nf_total_fat': 30,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 4,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:41.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd4030010b5',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Breakfast - Cinnamon Melts',
# ...
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 6,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 12,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 2,
#     u'nf_serving_size_qty': 12,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 180,
#     u'nf_sugars': 46,
#     u'nf_total_carbohydrate': 50,
#     u'nf_total_fat': 3.5,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 15,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:44.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd4030010fe',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Breakfast - Hotcakes and Sausage',
#     u'item_id': u'513fc9e73fe3ffd4030010fe',
#     u'item_name': u'Hotcakes And Sausage',
#     u'item_type': 1,
#     u'nf_calcium_dv': 15,
#     u'nf_calories': 520,
#     u'nf_calories_from_fat': 210,
#     u'nf_cholesterol': 50,
#     u'nf_dietary_fiber': 3,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 15,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 15,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 7,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'meal',
#     u'nf_serving_weight_grams': 192,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 930,
#     u'nf_sugars': 14,
#     u'nf_total_carbohydrate': 61,
#     u'nf_total_fat': 24,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:41.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd403001101',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe - Iced Caramel Mocha (Small)',
#     u'item_id': u'513fc9e73fe3ffd403001101',
#     u'item_name': u'Iced Caramel Mocha (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 25,
#     u'nf_calories': 270,
#     u'nf_calories_from_fat': 100,
#     u'nf_cholesterol': 35,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 2,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 8,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 6,
#     u'nf_serving_size_qty': 12,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 140,
#     u'nf_sugars': 32,
#     u'nf_total_carbohydrate': 37,
#     u'nf_total_fat': 11,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 10,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:44.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd403001106',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Beverages - Iced Coffee--Caramel (Medium)',
#     u'item_id': u'513fc9e73fe3ffd403001106',
#     u'item_name': u'Iced Coffee-- Caramel (Medium)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 4,
#     u'nf_calories': 180,
#     u'nf_calories_from_fat': 60,
#     u'nf_cholesterol': 25,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 1,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 4.5,
#     u'nf_serving_size_qty': 22,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 50,
#     u'nf_sugars': 28,
#     u'nf_total_carbohydrate': 29,
#     u'nf_total_fat': 7,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 4,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:44.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd40300110c',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe, Beverages - Iced Coffee-Hazelnut (Medium)',
#     u'item_id': u'513fc9e73fe3ffd40300110c',
#     u'item_name': u'Iced Coffee-- Hazelnut (Medium)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 4,
#     u'nf_calories': 180,
#     u'nf_calories_from_fat': 60,
#     u'nf_cholesterol': 25,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 1,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 4.5,
#     u'nf_serving_size_qty': 22,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 50,
#     u'nf_sugars': 28,
#     u'nf_total_carbohydrate': 29,
#     u'nf_total_fat': 7,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 4,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:44.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd403001113',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe - Iced Mocha (Small)',
#     u'item_id': u'513fc9e73fe3ffd403001113',
#     u'item_name': u'Iced Mocha (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 25,
#     u'nf_calories': 290,
#     u'nf_calories_from_fat': 100,
#     u'nf_cholesterol': 35,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 4,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 8,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 6,
#     u'nf_serving_size_qty': 12,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 125,
#     u'nf_sugars': 34,
#     u'nf_total_carbohydrate': 40,
#     u'nf_total_fat': 11,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 10,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:44.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd403001118',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe - Iced Nonfat Caramel Mocha (Medium)',
#     u'item_id': u'513fc9e73fe3ffd403001118',
#     u'item_name': u'Iced Nonfat Caramel Mocha (Medium)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 30,
#     u'nf_calories': 270,
#     u'nf_calories_from_fat': 45,
#     u'nf_cholesterol': 20,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 2,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 10,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 3,
#     u'nf_serving_size_qty': 16,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 170,
#     u'nf_sugars': 41,
#     u'nf_total_carbohydrate': 46,
#     u'nf_total_fat': 4.5,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 15,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:45.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd40300111e',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Condiments - Ketchup Packet',
#     u'item_id': u'513fc9e73fe3ffd40300111e',
#     u'item_name': u'Ketchup Packet',
#     u'item_type': 1,
#     u'nf_calcium_dv': 0,
#     u'nf_calories': 10,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 0,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'pkg',
#     u'nf_serving_weight_grams': 9,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 90,
#     u'nf_sugars': 2,
#     u'nf_total_carbohydrate': 2,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 2,
#     u'nf_vitamin_c_dv': 2,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:44.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd403001120',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Snacks & Sides - Kids Fries',
#     u'item_id': u'513fc9e73fe3ffd403001120',
#     u'item_name': u'Kids Fries',
#     u'item_type': 1,
#     u'nf_calcium_dv': 0,
#     u'nf_calories': 110,
#     u'nf_calories_from_fat': 50,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 2,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 1,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 1,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'fries',
#     u'nf_serving_weight_grams': 38,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 65,
#     u'nf_sugars': 0,
#     u'nf_total_carbohydrate': 15,
#     u'nf_total_fat': 5,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 15,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:48.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd403001125',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe - Latte with Sugar Free French Vanilla Syrup (Large)',
#     u'item_id': u'513fc9e73fe3ffd403001125',
#     u'item_name': u'Latte With Sugar Free French Vanilla Syrup (Large)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 50,
#     u'nf_calories': 330,
#     u'nf_calories_from_fat': 120,
#     u'nf_cholesterol': 40,
#     u'nf_dietary_fiber': 2,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 2,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 15,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 8,
#     u'nf_serving_size_qty': 20,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 240,
#     u'nf_sugars': 20,
#     u'nf_total_carbohydrate': 37,
#     u'nf_total_fat': 14,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 15,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:45.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd40300112b',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'McCafe, Beverages - Mango Pineapple Smoothie (Small)',
#     u'item_id': u'513fc9e73fe3ffd40300112b',
#     u'item_name': u'Mango Pineapple Smoothie (Small)',
#     u'item_type': 1,
#     u'nf_calcium_dv': 8,
#     u'nf_calories': 210,
#     u'nf_calories_from_fat': 5,
#     u'nf_cholesterol': 5,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 2,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 2,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 12,
#     u'nf_serving_size_unit': u'fl oz cup',
#     u'nf_serving_weight_grams': None,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 40,
#     u'nf_sugars': 46,
#     u'nf_total_carbohydrate': 50,
#     u'nf_total_fat': 0.5,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 30,
#     u'nf_vitamin_c_dv': 20,
#     u'nf_water_grams': None,
#     u'updated_at': u'2015-08-03T20:31:45.000Z'}}],
#  u'max_score': 1,
#  u'total': 359}

# %%
print "keys:", dat.keys()
print "length:", len(dat["hits"])
print "total:", dat["total"]
# Out:
# keys: [u'hits', u'total', u'max_score']
# length: 50
# total: 359
