# %%
import requests
import json
import os

# Load credential data from file
with open("credentials.json", "r") as f:
    credentials = json.load(f)

# Load restaurant ids from file
with open ("restaurant_ids.json", "r") as f:
    restaurant_ids = json.load(f)

# %%
restaurant_ids
# Out:
# [{u'id': u'513fbc1283aa2dc80c000053', u'name': u"McDonald's"},
#  {u'id': u'513fbc1283aa2dc80c00000f', u'name': u"Wendy's"},
#  {u'id': u'513fbc1283aa2dc80c000020', u'name': u'Taco Bell'},
#  {u'id': u'513fbc1283aa2dc80c00003a', u'name': u'Qdoba'},
#  {u'id': u'513fbc1283aa2dc80c000002', u'name': u'Chipotle'},
#  {u'id': u'513fbc1283aa2dc80c00003f', u'name': u'Five Guys'}]

# %%
def fetch_subset_menu_item_data(restaurant_id, credentials):
    """
    Helper function to fetch a subset of a restaurant's menu item data
    
    Parameters
    ----------
    restaurant_id : str
        Nutritionix unique ID specifying restaurant
    credentials : dict
        Contains API credentials "appID" and "appKey"
    """

    # Set base query URL
    query_url = u"https://api.nutritionix.com/v1_1/search"

    payload = dict(credentials)

    payload["brand_id"] = restaurant_id
    # Return all data from database
    payload["fields"] = "*"
    # "type" tells Nutritionix to return only restaurants (not food mfrs)
    payload["type"] = 1
    payload["offset"] = 0
    payload["limit"] = 50

    r = requests.get(query_url, payload)
    
    return r.json()

# %%
dat = fetch_subset_menu_item_data("513fbc1283aa2dc80c000053", credentials)

# %%
dat.keys()
# Out:
# [u'total_hits', u'hits', u'max_score']

# %%
len(dat["hits"])
# Out:
# 10

# %%
dat
# Out:
# {u'hits': [{u'_id': u'23cb59492691b7e43efa59ac',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb59492691b7e43efa59ac',
#     u'item_name': u'Southern Style Frozen Lemonade (Medium)',
#     u'nf_calcium_dv': 0,
#     u'nf_calories': 280,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 0,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 15.6,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 442,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 210,
#     u'nf_sugars': 70,
#     u'nf_total_carbohydrate': 76,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'old_api_id': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb594928b8f1d86ea1bb29',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb594928b8f1d86ea1bb29',
#     u'item_name': u'McCafe White Hot Chocolate (Medium)',
#     u'nf_calcium_dv': 50,
#     u'nf_calories': 420,
#     u'nf_calories_from_fat': 140,
#     u'nf_cholesterol': 50,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 14,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 9,
#     u'nf_serving_size_qty': 16.3,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 463,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 230,
#     u'nf_sugars': 57,
#     u'nf_total_carbohydrate': 59,
#     u'nf_total_fat': 15,
#     u'nf_trans_fatty_acid': 0.5,
#     u'nf_vitamin_a_dv': 15,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'old_api_id': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb59493b4ae57c2b4a14c4',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb59493b4ae57c2b4a14c4',
#     u'item_name': u'Southern Style Frozen Lemonade (Large)',
#     u'nf_calcium_dv': 0,
#     u'nf_calories': 360,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 0,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 19.5,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 553,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 270,
#     u'nf_sugars': 87,
#     u'nf_total_carbohydrate': 95,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'old_api_id': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb59494a4153911157ea4c',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb59494a4153911157ea4c',
#     u'item_name': u'Red Flash (Large)',
#     u'nf_calcium_dv': 0,
#     u'nf_calories': 300,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 0,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 25,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 709,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 0,
#     u'nf_sugars': 80,
#     u'nf_total_carbohydrate': 81,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'old_api_id': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb5949952638ce7e4c5b29',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb5949952638ce7e4c5b29',
#     u'item_name': u'Southern Style Iced Lemonade (Extra Large)',
#     u'nf_calcium_dv': 2,
#     u'nf_calories': 350,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 0,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 34.3,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 973,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 270,
#     u'nf_sugars': 86,
#     u'nf_total_carbohydrate': 94,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 15,
#     u'nf_water_grams': None,
#     u'old_api_id': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb5949b3ea4566e476311f',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb5949b3ea4566e476311f',
#     u'item_name': u'Premium Crispy Chicken Deluxe Sandwich',
#     u'nf_calcium_dv': 20,
#     u'nf_calories': 530,
#     u'nf_calories_from_fat': 200,
#     u'nf_cholesterol': 45,
#     u'nf_dietary_fiber': 3,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 15,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 25,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 4,
#     u'nf_serving_size_qty': 8,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 227,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 1000,
#     u'nf_sugars': 13,
#     u'nf_total_carbohydrate': 59,
#     u'nf_total_fat': 22,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 6,
#     u'nf_vitamin_c_dv': 10,
#     u'nf_water_grams': None,
#     u'old_api_id': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb5949c0446d93cfe1e2d7',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb5949c0446d93cfe1e2d7',
#     u'item_name': u'Iced Classic Lemonade (Medium)',
#     u'nf_calcium_dv': 2,
#     u'nf_calories': 130,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 0,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 15.6,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 441,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 15,
#     u'nf_sugars': 28,
#     u'nf_total_carbohydrate': 32,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 0,
#     u'nf_vitamin_c_dv': 40,
#     u'nf_water_grams': None,
#     u'old_api_id': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb5949e2de735b09fc2dd8',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb5949e2de735b09fc2dd8',
#     u'item_name': u'Go-Gurt Strawberry Banana Flavored Low Fat Yogurt Tube',
#     u'nf_calcium_dv': 10,
#     u'nf_calories': 50,
#     u'nf_calories_from_fat': 5,
#     u'nf_cholesterol': 5,
#     u'nf_dietary_fiber': 0,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 0,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 3,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 2.3,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 64,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 30,
#     u'nf_sugars': 6,
#     u'nf_total_carbohydrate': 9,
#     u'nf_total_fat': 0.5,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 4,
#     u'nf_vitamin_c_dv': 0,
#     u'nf_water_grams': None,
#     u'old_api_id': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'23cb5949eef0eb1fb81ad5aa',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': None,
#     u'item_id': u'23cb5949eef0eb1fb81ad5aa',
#     u'item_name': u'Frozen Classic Lemonade (Extra Large)',
#     u'nf_calcium_dv': 4,
#     u'nf_calories': 390,
#     u'nf_calories_from_fat': 0,
#     u'nf_cholesterol': 0,
#     u'nf_dietary_fiber': 1,
#     u'nf_ingredient_statement': None,
#     u'nf_iron_dv': 2,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 1,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 0,
#     u'nf_serving_size_qty': 31.2,
#     u'nf_serving_size_unit': u'oz',
#     u'nf_serving_weight_grams': 885,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 25,
#     u'nf_sugars': 89,
#     u'nf_total_carbohydrate': 100,
#     u'nf_total_fat': 0,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 2,
#     u'nf_vitamin_c_dv': 80,
#     u'nf_water_grams': None,
#     u'old_api_id': None,
#     u'updated_at': u'2015-08-03T20:35:54.000Z'}},
#   {u'_id': u'513fc9e73fe3ffd403001097',
#    u'_index': u'f762ef22-e660-434f-9071-a10ea6691c27',
#    u'_score': 1,
#    u'_type': u'item',
#    u'fields': {u'allergen_contains_eggs': None,
#     u'allergen_contains_fish': None,
#     u'allergen_contains_gluten': None,
#     u'allergen_contains_milk': None,
#     u'allergen_contains_peanuts': None,
#     u'allergen_contains_shellfish': None,
#     u'allergen_contains_soybeans': None,
#     u'allergen_contains_tree_nuts': None,
#     u'allergen_contains_wheat': None,
#     u'brand_id': u'513fbc1283aa2dc80c000053',
#     u'brand_name': u"McDonald's",
#     u'item_description': u'Breakfast - Bacon, Egg & Cheese Biscuit (Large Size Biscuit)',
#     u'item_id': u'513fc9e73fe3ffd403001097',
#     u'item_name': u'Bacon, Egg & Cheese Biscuit (Large Size Biscuit)',
#     u'nf_calcium_dv': 20,
#     u'nf_calories': 520,
#     u'nf_calories_from_fat': 270,
#     u'nf_cholesterol': 250,
#     u'nf_dietary_fiber': 3,
#     u'nf_ingredient_statement': u'Biscuit (Large) Allergens: WHEAT, MILK AND SOY LECITHIN, SOY LECITHIN Ingredients: Enriched Flour (Bleached Wheat Flour, Niacin, Reduced Iron, Thiamin Mononitrate, Riboflavin, Folic Acid), Cultured Nonfat Buttermilk, Vegetable Oil (Palm Oil, Palm Kernel Oil), Water, Leavening (Baking Soda, Sodium Aluminum Phosphate, Monocalcium Phosphate), Contains 2% Or Less: Salt, Sugar, Modified Cellulose, Wheat Protein Isolate, Natural Flavor (Dairy and Vegetable Source), Soy Lecithin. CONTAINS: WHEAT, MILK AND SOY LECITHIN. Prepared with Liquid Margarine: Liquid Soybean Oil and Hydrogenated Cottonseed and Soybean Oils, Water, Partially Hydrogenated Soybean Oil, Salt, Soy Lecithin, Mono and Diglycerides, Sodium Benzoate and Potassium Sorbate (Preservatives), Artificial Flavor, Citric Acid, Vitamin A Palmitate, Beta Carotene (Color). CONTAINS: SOY LECITHIN. Bacon Pork Bellies Cured with Water, Salt, Sugar, Natural Smoke Flavor (Plant Source), Sodium Phosphate, Sodium Erythorbate, Sodium Nitrite. Folded Egg Allergens: EGG, SOY LECITHIN, SOY LECITHIN Pasteurized Whole Eggs, Modified Food Starch, Soybean Oil, Natural Flavors (Plant Source), Sodium Acid Pyrophosphate, Carrageenan, Flavor Enhancer (Salt, Maltodextrin, Natural Flavor [Plant Source], Spices, Herb, Turmeric [Color]), Monosodium Phosphate, Citric Acid, Soy Lecithin. CONTAINS: EGG, SOY LECITHIN. Prepared with Liquid Margarine: Liquid Soybean Oil and Hydrogenated Cottonseed and Soybean Oils, Water, Partially Hydrogenated Soybean Oil, Salt, Soy Lecithin, Mono and Diglycerides, Sodium Benzoate and Potassium Sorbate (Preservatives), Artificial Flavor, Citric Acid, Vitamin A Palmitate, Beta Carotene (Color). CONTAINS: SOY LECITHIN. Pasteurized Process American Cheese Allergens: MILK AND SOY LECITHIN Milk, Cream, Water, Cheese Culture, Sodium Citrate, Contains 2% or Less of: Salt, Citric Acid, Sodium Phosphate, Sorbic Acid (Preservative), Lactic Acid, Acetic Acid, Enzymes, Sodium Pyrophosphate, Natural Flavor (Dairy Source), Color Added, Soy Lecithin (Added for Slice Separation). CONTAINS: MILK AND SOY LECITHIN',
#     u'nf_iron_dv': 20,
#     u'nf_monounsaturated_fat': None,
#     u'nf_polyunsaturated_fat': None,
#     u'nf_protein': 19,
#     u'nf_refuse_pct': None,
#     u'nf_saturated_fat': 14,
#     u'nf_serving_size_qty': 1,
#     u'nf_serving_size_unit': u'biscuit',
#     u'nf_serving_weight_grams': 164,
#     u'nf_servings_per_container': None,
#     u'nf_sodium': 1410,
#     u'nf_sugars': 4,
#     u'nf_total_carbohydrate': 43,
#     u'nf_total_fat': 30,
#     u'nf_trans_fatty_acid': 0,
#     u'nf_vitamin_a_dv': 15,
#     u'nf_vitamin_c_dv': 8,
#     u'nf_water_grams': None,
#     u'old_api_id': None,
#     u'updated_at': u'2015-08-03T20:31:39.000Z'}}],
#  u'max_score': 1,
#  u'total_hits': 359}
